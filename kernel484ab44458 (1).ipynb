# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
train= pd.read_csv("/kaggle/input/widsdatathon2020/training_v2.csv", header=0)
test = pd.read_csv("/kaggle/input/widsdatathon2020/unlabeled.csv")

# %%
print(train.shape)
print(test.shape)

# %%
train_categorical_cols = []
train_numerical_cols = []
for c in  train.columns:
    if(train[c].dtype=='object'):
        train_categorical_cols.append(c)
    else:
        train_numerical_cols.append(c)
test_categorical_cols = []
test_numerical_cols = []
for c in  test.columns:
    if(test[c].dtype=='object'):
        test_categorical_cols.append(c)
    else:
        test_numerical_cols.append(c)

print(train_categorical_cols)
print(len(train_categorical_cols))
print(len(train_numerical_cols))
print(test_categorical_cols)
print(len(test_categorical_cols))
print(len(test_numerical_cols))

# %%
train[train_categorical_cols] = train[train_categorical_cols].fillna("")
test[test_categorical_cols] = test[test_categorical_cols].fillna("")

# %%
train.fillna(train.mean(), inplace=True)

# %%
test.fillna(test.mean(), inplace=True)

# %%
std_scale = StandardScaler().fit(train[train_numerical_cols])
train[train_numerical_cols] = std_scale.transform(train[train_numerical_cols])

# %%
train_allcols = train.columns.values.tolist()
test_allcols = test.columns.values.tolist()
allcols = train.columns.values.tolist()
inputcols = allcols[4:]
inputcols.remove('readmission_status')
outputcols = allcols[3]
print(outputcols)

# %%
X = train[inputcols]
y = train[outputcols]

# %%
label = LabelEncoder()
for c in  X.columns:
    if(X[c].dtype == 'object'):
        X[c]=label.fit_transform(X[c])
    else:
        X[c]=X[c]

# %%
X.head()
# Out:
#         age           bmi  elective_surgery  ethnicity  gender    height  \
# 0  0.347324 -7.951567e-01         -0.474441          3       2  0.994578
# 1  0.896647 -2.174940e-01         -0.474441          3       1 -0.899694
# 2 -2.277221  3.404616e-01         -0.474441          3       1  0.285392
# 3  1.140791 -8.062419e-01          2.107744          3       1 -0.423793
# 4 -2.643436 -8.051550e-14         -0.474441          3       2  1.713095
#
#    hospital_admit_source  icu_admit_source    icu_id  icu_stay_type  icu_type  \
# 0                      5                 2 -1.818248              0         2
# 1                      5                 2 -1.826982              0         5
# 2                      4                 1 -1.813881              0         5
# 3                      9                 3 -1.818248              0         2
# 4                      0                 1 -1.822615              0         5
#
#    pre_icu_los_days        weight  albumin_apache  apache_2_diagnosis  \
# 0         -0.118219 -4.110915e-01   -1.386008e+00           -0.849116
# 1          0.036986 -5.612680e-01    1.939526e-14           -0.907756
# 2         -0.335674  4.574969e-01    1.939526e-14           -0.743566
# 3         -0.335674 -9.062681e-01    1.939526e-14            0.206390
# 4         -0.306364 -6.633127e-14    1.939526e-14           -0.778749
#
#    apache_3j_diagnosis  apache_post_operative  arf_apache  bilirubin_apache  \
# 0            -0.122062              -0.501727   -0.170324     -5.706394e-01
# 1            -0.771391              -0.501727   -0.170324      1.084532e-14
# 2             0.314487              -0.501727   -0.170324      1.084532e-14
# 3             1.406837               1.993116   -0.170324      1.084532e-14
# 4             0.092934              -0.501727   -0.170324      1.084532e-14
#
#      bun_apache  creatinine_apache   fio2_apache  gcs_eyes_apache  \
# 0  2.816280e-01       7.573758e-01 -8.050604e-14        -0.493791
# 1 -9.157075e-01      -6.765098e-01  3.221256e+00        -2.617396
# 2  5.800623e-16       7.347382e-15 -8.050604e-14        -0.493791
# 3  5.800623e-16       7.347382e-15  3.385420e-02         0.568012
# 4  5.800623e-16       7.347382e-15 -8.050604e-14         0.000000
#
#    gcs_motor_apache  gcs_unable_apache  gcs_verbal_apache  glucose_apache  \
# 0      4.147661e-01          -0.098641           0.003382    9.011102e-02
# 1     -1.938273e+00          -0.098641          -1.939744   -1.799926e-01
# 2      4.147661e-01          -0.098641           0.651091   -8.010582e-15
# 3      4.147661e-01          -0.098641           0.651091    2.897528e-01
# 4     -6.966396e-16           0.000000           0.000000   -8.010582e-15
#
#    heart_rate_apache  hematocrit_apache  intubated_apache  map_apache  \
# 0           0.595402      -9.187153e-01         -0.423752   -1.148601
# 1           0.660502       6.429598e-01         -0.423752   -1.005073
# 2           0.074606      -7.008233e-15         -0.423752   -0.478805
# 3           0.465203      -1.165296e+00          2.378413   -0.670176
# 4          -1.292483      -7.008233e-15         -0.423752    0.358439
#
#    paco2_apache  paco2_for_ph_apache   pao2_apache     ph_apache  \
# 0 -2.407353e-15        -2.407353e-15  2.139204e-15  1.905845e-14
# 1 -8.780532e-01        -8.780532e-01 -2.010833e+00  2.062217e+00
# 2 -2.407353e-15        -2.407353e-15  2.139204e-15  1.905845e-14
# 3 -2.063870e+00        -2.063870e+00  2.722525e-01  7.747422e-01
# 4 -2.407353e-15        -2.407353e-15  2.139204e-15  1.905845e-14
#
#    resprate_apache  sodium_apache  temp_apache  urineoutput_apache  \
# 0         0.679073      -0.841450     3.542215        1.610465e-15
# 1         0.479130       1.492157    -1.613620        1.610465e-15
# 2         0.745721       0.000000     0.350508        1.610465e-15
# 3        -1.453655       0.000000    -1.981894        1.610465e-15
# 4        -0.653882       0.000000     0.350508        1.610465e-15
#
#    ventilated_apache    wbc_apache  d1_diasbp_invasive_max  \
# 0          -0.697755  3.260997e-01           -2.964296e+00
# 1           1.444428  9.396099e-02           -1.285990e-15
# 2          -0.697755  1.089812e-14           -1.285990e-15
# 3           1.444428 -6.853618e-01           -1.516400e+00
# 4          -0.697755  1.089812e-14           -1.285990e-15
#
#    d1_diasbp_invasive_min  d1_diasbp_max  d1_diasbp_min  \
# 0           -2.253897e+00      -1.035966      -0.989161
# 1           -1.086621e-15       0.329018      -1.440102
# 2           -1.086621e-15      -0.024867      -0.162437
# 3           -2.559754e+00      -2.047065      -0.613378
# 4           -1.086621e-15       0.531238       0.513973
#
#    d1_diasbp_noninvasive_max  d1_diasbp_noninvasive_min  d1_heartrate_max  \
# 0                  -1.047224                  -0.998267          0.727253
# 1                   0.324651                  -1.450565          0.681798
# 2                  -0.031020                  -0.169054         -0.318210
# 3                  -2.063428                  -0.621352          0.590888
# 4                   0.527892                   0.509393         -0.636395
#
#    d1_heartrate_min  d1_mbp_invasive_max  d1_mbp_invasive_min  d1_mbp_max  \
# 0          0.098124        -1.935218e+00        -2.418484e+00   -0.753074
# 1          0.098124         1.125025e-15        -1.539931e-15    0.738510
# 2         -0.135763         1.125025e-15        -1.539931e-15   -0.127571
# 3          1.267560        -9.060519e-01        -1.118128e+00   -0.993652
# 4         -0.603537         1.125025e-15        -1.539931e-15   -0.031340
#
#    d1_mbp_min  d1_mbp_noninvasive_max  d1_mbp_noninvasive_min  \
# 0   -1.205040               -0.759271               -1.216220
# 1   -1.715870                0.750460               -1.729894
# 2    0.199744               -0.126158                0.196381
# 3    1.221404               -1.002776                1.223728
# 4    1.604527               -0.028756                1.608983
#
#    d1_resprate_max  d1_resprate_min  d1_spo2_max  d1_spo2_min  \
# 0         0.479167        -0.563143     0.423340    -1.643545
# 1         0.291891        -0.167438     0.423340    -2.043074
# 2        -0.738127        -0.958848    -0.693411     0.054453
# 3        -0.550851        -1.156700     0.423340     0.453982
# 4        -1.019041         0.623971     0.423340     0.553864
#
#    d1_sysbp_invasive_max  d1_sysbp_invasive_min  d1_sysbp_max  d1_sysbp_min  \
# 0              -1.964150          -2.344888e+00     -0.674415     -1.157987
# 1               0.000000           3.353103e-15      0.414622     -1.448404
# 2               0.000000           3.353103e-15     -0.013214      0.390909
# 3               0.591886          -1.243771e+00      0.375727     -0.625554
# 4               0.000000           3.353103e-15     -0.052108      1.116953
#
#    d1_sysbp_noninvasive_max  d1_sysbp_noninvasive_min  d1_temp_max  \
# 0                 -0.672017                 -1.165366     3.821794
# 1                  0.419708                 -1.456789    -1.437959
# 2                 -0.009184                  0.388888    -0.415229
# 3                  0.380718                 -0.631091     1.045813
# 4                 -0.048174                  1.117445    -0.123021
#
#    d1_temp_min  h1_diasbp_invasive_max  h1_diasbp_invasive_min  h1_diasbp_max  \
# 0     1.266390            2.042419e-15                0.000000      -0.407628
# 1    -1.588260            2.042419e-15                0.000000      -0.795607
# 2     0.586712            2.042419e-15                0.000000       0.700883
# 3    -1.996068           -8.580707e-01               -2.007051      -0.740181
# 4     0.586712            2.042419e-15                0.000000       1.310565
#
#    h1_diasbp_min  h1_diasbp_noninvasive_max  h1_diasbp_noninvasive_min  \
# 0       0.010092              -4.403744e-01              -1.718178e-02
# 1      -0.925242              -8.352817e-01              -9.695514e-01
# 2      -0.301686               6.879323e-01              -3.346383e-01
# 3      -1.174665               8.017101e-16              -4.511329e-16
# 4       0.321870               1.308501e+00               3.002748e-01
#
#    h1_heartrate_max  h1_heartrate_min  h1_mbp_invasive_max  \
# 0          1.245787          1.218709        -2.150716e-15
# 1          1.013110          0.818086        -2.150716e-15
# 2          0.175475         -0.283627        -2.150716e-15
# 3          0.361616          0.617774        -2.182090e-01
# 4         -0.150272         -0.383783        -2.150716e-15
#
#    h1_mbp_invasive_min  h1_mbp_max  h1_mbp_min  h1_mbp_noninvasive_max  \
# 0         1.723599e-15   -0.280549    0.300422           -2.867673e-01
# 1         1.723599e-15   -0.330531   -1.201694           -3.380295e-01
# 2         1.723599e-15   -0.030637    0.193128           -3.045619e-02
# 3        -6.029361e-01    0.019346   -0.450636           -7.284799e-16
# 4         1.723599e-15    0.619135    0.675951            6.359526e-01
#
#    h1_mbp_noninvasive_min  h1_resprate_max  h1_resprate_min  h1_spo2_max  \
# 0                0.289759     4.589908e-01         0.133041     0.622974
# 1               -1.243740     1.140717e+00         1.820362    -0.970014
# 2                0.180224    -3.590809e-01        -0.204423    -0.014221
# 3                0.000000    -1.449843e+00        -1.048084     0.622974
# 4                0.673134     4.843957e-16         0.000000     0.622974
#
#    h1_spo2_min  h1_sysbp_invasive_max  h1_sysbp_invasive_min  h1_sysbp_max  \
# 0    -3.271545               0.000000          -1.187104e-15     -0.083209
# 1    -3.889567               0.000000          -1.187104e-15     -1.416104
# 2    -0.644953               0.000000          -1.187104e-15      0.546213
# 3     0.591090              -0.216217          -7.379567e-01      0.101915
# 4     0.745595               0.000000          -1.187104e-15     -0.120234
#
#    h1_sysbp_min  h1_sysbp_noninvasive_max  h1_sysbp_noninvasive_min  \
# 0     -0.052430                 -0.077393                 -0.060685
# 1     -1.745822                 -1.433391                 -1.783767
# 2      0.293946                  0.562939                  0.291764
# 3     -0.398805                  0.000000                  0.000000
# 4      0.140001                 -0.115060                  0.135120
#
#     h1_temp_max   h1_temp_min  d1_albumin_max  d1_albumin_min  \
# 0  4.239867e+00  1.315245e+00   -1.465665e+00   -1.311405e+00
# 1 -6.245581e-01 -4.534500e-01   -3.000779e+00   -2.841360e+00
# 2 -1.650499e-02  1.361150e-01   -1.460845e-14    7.764988e-15
# 3 -1.688651e+00 -2.664319e+00   -1.460845e-14    7.764988e-15
# 4 -3.564394e-13 -5.445845e-13   -1.460845e-14    7.764988e-15
#
#    d1_bilirubin_max  d1_bilirubin_min  d1_bun_max    d1_bun_min  \
# 0     -5.375520e-01     -5.139694e-01    0.275924  3.524088e-01
# 1     -4.646446e-01     -4.370065e-01   -0.762506 -8.350036e-01
# 2      2.072151e-14      1.982345e-14    0.000000  7.834424e-15
# 3      2.072151e-14      1.982345e-14    0.000000  7.834424e-15
# 4      2.072151e-14      1.982345e-14    0.000000  7.834424e-15
#
#    d1_calcium_max  d1_calcium_min  d1_creatinine_max  d1_creatinine_min  \
# 0    1.778148e-01   -1.074374e+00       7.187797e-01       6.862000e-01
# 1    3.246245e-01   -2.474818e-01      -5.479784e-01      -6.415915e-01
# 2   -5.998088e-14   -1.052679e-13       1.250119e-15       1.076920e-14
# 3   -5.998088e-14   -1.052679e-13       1.250119e-15       1.076920e-14
# 4   -5.998088e-14   -1.052679e-13       1.250119e-15       1.076920e-14
#
#    d1_glucose_max  d1_glucose_min   d1_hco3_max   d1_hco3_min  \
# 0       -0.079120   -1.452686e-01 -1.342924e+00 -1.790633e+00
# 1       -0.353262    3.676721e-01  6.590126e-01  6.201126e-01
# 2        0.000000    3.836487e-16  1.778077e-15  3.893040e-15
# 3        0.123507   -7.122031e-01  1.778077e-15  3.893040e-15
# 4        0.000000    3.836487e-16  1.778077e-15  3.893040e-15
#
#    d1_hemaglobin_max  d1_hemaglobin_min  d1_hematocrit_max  d1_hematocrit_min  \
# 0      -1.261762e+00      -9.052634e-01      -1.223557e+00      -8.674718e-01
# 1      -7.338019e-02       9.659990e-02       4.062581e-01       4.919048e-01
# 2      -1.583242e-14       2.507712e-14      -8.289226e-14       4.551920e-14
# 3       7.516750e-02      -9.052634e-01      -9.126455e-02      -1.101847e+00
# 4      -1.583242e-14       2.507712e-14      -8.289226e-14       4.551920e-14
#
#      d1_inr_max    d1_inr_min  d1_lactate_max  d1_lactate_min  \
# 0 -5.742334e-14 -8.701194e-14   -1.049287e+00   -1.056826e+00
# 1 -5.111483e-01 -4.028288e-01    3.692064e-01    1.291409e+00
# 2 -5.742334e-14 -8.701194e-14    2.004347e-15   -2.919913e-15
# 3  6.075216e-03 -8.431288e-01    2.004347e-15   -2.919913e-15
# 4 -5.742334e-14 -8.701194e-14    2.004347e-15   -2.919913e-15
#
#    d1_platelets_max  d1_platelets_min  d1_potassium_max  d1_potassium_min  \
# 0          0.312731      4.447369e-01     -3.983978e-01     -9.747938e-01
# 1          4.225739      3.562664e+00     -8.169942e-02     -2.455103e-01
# 2          0.000000     -5.233276e-15     -1.125139e-14     -4.938971e-14
# 3         -0.109971     -1.887571e+00      1.185094e+00     -7.924729e-01
# 4          0.000000     -5.233276e-15     -1.125139e-14     -4.938971e-14
#
#    d1_sodium_max  d1_sodium_min    d1_wbc_max    d1_wbc_min  h1_albumin_max  \
# 0  -6.881428e-01  -8.017901e-01  2.581758e-01  5.060009e-01    4.139312e-15
# 1   1.294278e+00   1.567729e+00  1.721020e+00  2.517715e-01    4.139312e-15
# 2  -1.252084e-14   1.836703e-14 -2.937472e-14 -4.838594e-15    4.139312e-15
# 3  -1.252084e-14   1.836703e-14 -5.527487e-01 -6.017130e-01    4.139312e-15
# 4  -1.252084e-14   1.836703e-14 -2.937472e-14 -4.838594e-15    4.139312e-15
#
#    h1_albumin_min  h1_bilirubin_max  h1_bilirubin_min    h1_bun_max  \
# 0   -4.139166e-15     -1.570497e-15     -3.928146e-16  3.893309e-16
# 1   -4.139166e-15     -1.570497e-15     -3.928146e-16 -1.845941e+00
# 2   -4.139166e-15     -1.570497e-15     -3.928146e-16  3.893309e-16
# 3   -4.139166e-15     -1.570497e-15     -3.928146e-16  3.893309e-16
# 4   -4.139166e-15     -1.570497e-15     -3.928146e-16  3.893309e-16
#
#      h1_bun_min  h1_calcium_max  h1_calcium_min  h1_creatinine_max  \
# 0 -7.792894e-16    9.684836e-15    1.930526e-14       9.891145e-16
# 1 -1.844655e+00    8.622023e-01    8.632049e-01      -1.442125e+00
# 2 -7.792894e-16    9.684836e-15    1.930526e-14       9.891145e-16
# 3 -7.792894e-16    9.684836e-15    1.930526e-14       9.891145e-16
# 4 -7.792894e-16    9.684836e-15    1.930526e-14       9.891145e-16
#
#    h1_creatinine_min  h1_glucose_max  h1_glucose_min   h1_hco3_max  \
# 0      -3.303743e-16   -1.838223e-15        0.000000  4.961071e-15
# 1      -1.441428e+00   -3.716505e-01       -0.278679  2.096164e+00
# 2      -3.303743e-16   -1.838223e-15        0.000000  4.961071e-15
# 3      -3.303743e-16   -1.838223e-15        0.000000  4.961071e-15
# 4      -3.303743e-16   -1.838223e-15        0.000000  4.961071e-15
#
#     h1_hco3_min  h1_hemaglobin_max  h1_hemaglobin_min  h1_hematocrit_max  \
# 0  1.653347e-15       3.326506e-15       1.637785e-15      -6.978137e-15
# 1  2.130631e+00       1.061189e-01       2.406748e-01       1.056176e+00
# 2  1.653347e-15       3.326506e-15       1.637785e-15      -6.978137e-15
# 3  1.653347e-15       3.870173e-01       5.172721e-01       1.068270e-01
# 4  1.653347e-15       3.326506e-15       1.637785e-15      -6.978137e-15
#
#    h1_hematocrit_min    h1_inr_max    h1_inr_min  h1_lactate_max  \
# 0      -6.790079e-15 -5.742334e-14 -8.701194e-14    1.608848e-15
# 1       1.171220e+00 -5.111483e-01 -4.028288e-01    5.206447e-01
# 2      -6.790079e-15 -5.742334e-14 -8.701194e-14    1.608848e-15
# 3       2.474554e-01  6.075216e-03 -8.431288e-01    1.608848e-15
# 4      -6.790079e-15 -5.742334e-14 -8.701194e-14    1.608848e-15
#
#    h1_lactate_min  h1_platelets_max  h1_platelets_min  h1_potassium_max  \
# 0    1.632410e-15      7.335802e-16     -7.325293e-16     -5.033478e-15
# 1    5.862476e-01      9.315133e+00      9.317626e+00     -3.242359e-03
# 2    1.632410e-15      7.335802e-16     -7.325293e-16     -5.033478e-15
# 3    1.632410e-15     -3.951493e+00     -3.929996e+00     -5.033478e-15
# 4    1.632410e-15      7.335802e-16     -7.325293e-16     -5.033478e-15
#
#    h1_potassium_min  h1_sodium_max  h1_sodium_min    h1_wbc_max    h1_wbc_min  \
# 0      2.552430e-15  -1.084051e-14       0.000000  1.227996e-15 -1.230506e-15
# 1      1.350491e-01   2.578524e+00       2.740258 -2.627674e-01 -2.505804e-01
# 2      2.552430e-15  -1.084051e-14       0.000000  1.227996e-15 -1.230506e-15
# 3      2.552430e-15  -1.084051e-14       0.000000 -1.610803e+00 -1.601371e+00
# 4      2.552430e-15  -1.084051e-14       0.000000  1.227996e-15 -1.230506e-15
#
#    d1_arterial_pco2_max  d1_arterial_pco2_min  d1_arterial_ph_max  \
# 0          5.700764e-15         -1.091556e-15        1.000163e-12
# 1         -9.454578e-01         -2.202740e-01        1.221878e+00
# 2          5.700764e-15         -1.091556e-15        1.000163e-12
# 3         -9.454578e-01         -1.756503e+00        1.020792e+00
# 4          5.700764e-15         -1.091556e-15        1.000163e-12
#
#    d1_arterial_ph_min  d1_arterial_po2_max  d1_arterial_po2_min  \
# 0        3.120067e-13         1.769582e-15        -7.725601e-16
# 1        1.916353e+00        -1.788683e+00        -1.427366e+00
# 2        3.120067e-13         1.769582e-15        -7.725601e-16
# 3        2.362787e-01         2.663023e+00        -4.108156e-02
# 4        3.120067e-13         1.769582e-15        -7.725601e-16
#
#    d1_pao2fio2ratio_max  d1_pao2fio2ratio_min  h1_arterial_pco2_max  \
# 0         -5.861936e-15         -5.480431e-15          3.515394e-15
# 1         -3.401143e+00         -2.772237e+00         -1.264648e+00
# 2         -5.861936e-15         -5.480431e-15          3.515394e-15
# 3          8.372648e-01          2.112023e-01         -1.429564e+00
# 4         -5.861936e-15         -5.480431e-15          3.515394e-15
#
#    h1_arterial_pco2_min  h1_arterial_ph_max  h1_arterial_ph_min  \
# 0              0.000000       -8.222988e-14       -4.033276e-14
# 1             -1.091357        2.583917e+00        2.772717e+00
# 2              0.000000       -8.222988e-14       -4.033276e-14
# 3             -1.775223        7.322650e-01        2.751311e-01
# 4              0.000000       -8.222988e-14       -4.033276e-14
#
#    h1_arterial_po2_max  h1_arterial_po2_min  h1_pao2fio2ratio_max  \
# 0        -2.416711e-15        -6.961635e-16         -6.171232e-16
# 1        -2.398738e+00        -2.281727e+00         -4.199420e+00
# 2        -2.416711e-15        -6.961635e-16         -6.171232e-16
# 3         3.680939e+00         2.960006e+00          2.010524e+00
# 4        -2.416711e-15        -6.961635e-16         -6.171232e-16
#
#    h1_pao2fio2ratio_min  apache_4a_hospital_death_prob  \
# 0         -1.902695e-15                   5.584625e-02
# 1         -4.126789e+00                   1.619679e+00
# 2         -1.902695e-15                  -3.668114e-01
# 3          2.255313e+00                  -1.977483e-01
# 4         -1.902695e-15                   1.689279e-13
#
#    apache_4a_icu_death_prob      aids  cirrhosis  diabetes_mellitus  \
# 0              2.910385e-02 -0.029405   -0.12676           1.862175
# 1              1.184559e+00 -0.029405   -0.12676           1.862175
# 2             -2.116159e-01 -0.029405   -0.12676          -0.541226
# 3             -6.718405e-02 -0.029405   -0.12676          -0.541226
# 4              1.436483e-13 -0.029405   -0.12676          -0.541226
#
#    hepatic_failure  immunosuppression  leukemia  lymphoma  \
# 0        -0.115168          -0.164559 -0.084689 -0.064666
# 1        -0.115168          -0.164559 -0.084689 -0.064666
# 2        -0.115168          -0.164559 -0.084689 -0.064666
# 3        -0.115168          -0.164559 -0.084689 -0.064666
# 4        -0.115168          -0.164559 -0.084689 -0.064666
#
#    solid_tumor_with_metastasis  apache_3j_bodysystem  apache_2_bodysystem
# 0                    -0.145734                    10                    1
# 1                    -0.145734                     9                    7
# 2                    -0.145734                     6                    4
# 3                    -0.145734                     1                    1
# 4                    -0.145734                    11                    8

# %%
print(len(inputcols))
# Out:
# 181

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(181,)),
    keras.layers.Dense(16, activation=tf.nn.relu),
	keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid),
])

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(X, y, epochs=200, batch_size=5)
# Out:
# Train on 91713 samples
# Epoch 1/200
# 91713/91713 [==============================] - 61s 664us/sample - loss: -67622.7687 - accuracy: 0.0000e+00
# Epoch 2/200
# 54595/91713 [================>.............] - ETA: 23s - loss: -479551.1502 - accuracy: 0.0000e+00

# %%
print(model.predict(a))

# %%
model = Sequential()
model.add(Dense(181, input_dim=90, activation='relu'))
model.add(Dense(181, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam')
model.fit(X, y, epochs=200, verbose=0)

# %%
# Baseline model for the neural network. We choose a hidden layer of 10 neurons. The lesser number of neurons helps to eliminate the redundancies in the data and select the more important features.
def create_baseline():
    # create model
    model = Sequential()
    model.add(Dense(10, input_dim=181, kernel_initializer='normal', activation='relu'))
    model.add(Dense(1, kernel_initializer='normal', activation='sigmoid'))
    # Compile model. We use the the logarithmic loss function, and the Adam gradient optimizer.
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
# Evaluate model using standardized dataset. 
estimators = []
estimators.append(('standardize', StandardScaler()))
estimators.append(('mlp', KerasClassifier(build_fn=create_baseline, epochs=200, batch_size=5, verbose=0)))
pipeline = Pipeline(estimators)
kfold = StratifiedKFold(n_splits=10, shuffle=True)
results = cross_val_score(pipeline, X, y, cv=kfold)
print("Results: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))

# %%
pipeline.getModel()

# %%
print('completed')
